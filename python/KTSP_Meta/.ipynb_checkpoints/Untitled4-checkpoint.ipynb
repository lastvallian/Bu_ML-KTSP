# %%
import sys
sys.path.append(r"C:\Users\Administrator\KTSP")
from sklearn.neighbors import KNeighborsClassifier
from utils.metrics import evaluate_model
import KTSP_Meta.utils.data_utils as du
print(du.__file__)

#Create a simple model
model = {"knn": KNeighborsClassifier()} 

from KTSP_Meta.pipe_line.KTSP_Meta_Pipeline import MetaPipeline

p = MetaPipeline(model)
p.run(r"D:\fitchburg\Bu_ML\KTSP\Data\Leukemia.txt")
# Out:
# C:\Users\Administrator\KTSP\KTSP_Meta\utils\data_utils.py
# STEP 1: start loading data
# X shape: (72, 7129)
# y shape: (72,)
# label unique: [0 1]
# STEP 2: data loaded
#
# === Trainingknn===
# STEP 3: start training
# STEP 4: training finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11 from KTSP_Meta.pipe_line.KTSP_Meta_Pipeline import MetaPipeline
#      13 p = MetaPipeline(model)
# ---> 14 p.run(r"D:\fitchburg\Bu_ML\KTSP\Data\Leukemia.txt")
#
# File ~\KTSP\KTSP_Meta\pipe_line\KTSP_Meta_Pipeline.py:44, in MetaPipeline.run(self, file_path, visualize)
#      41 scoreS=model.predict_proba(X_test)
#      42 print("STEP 4: training finished")
# ---> 44 results[name]=evaluate_model(
#      45 )
#      47 if visualize:
#      48     visualize_model(
#      49         y_test=y_test,
#      50         y_pred=y_pred,
#    (...)
# ...

# %%
import KTSP_Meta.utils.data_utils as du
print(du.__file__)
