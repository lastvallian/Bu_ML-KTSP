# %%
import os

for root, dirs, files in os.walk("."):
    level = root.replace(".", "").count(os.sep)
    indent = "  " * level
    print(f"{indent}{os.path.basename(root)}/")
    for f in files:
        if f.endswith(".py"):
            print(f"{indent}  ├── {f}")
# Out:
# ./
#   ├── KTSP_Meta_Pipeline.py
#   ├── main.py
#   ├── run_pipeline.py
#   ├── __init__.py
#   .ipynb_checkpoints/
#   models/
#     ├── Ktsp_model.py
#     ├── multi_model_trainer.py
#     ├── __init__.py
#     .ipynb_checkpoints/
#       ├── __init__-checkpoint.py
#     __pycache__/
#   pipe_line/
#     ├── KTSP_Meta_Pipeline.py
#     ├── meta_pipeline.py
#     ├── __init__.py
#     .ipynb_checkpoints/
#     __pycache__/
#   utils/
#     ├── data_utils.py
#     ├── metrics.py
#     ├── SubspaceModule.py
#     ├── visualize.py
#     ├── __init__.py
#     .ipynb_checkpoints/
#     __pycache__/
#   __pycache__/
